# %% [markdown]
# <a href="https://colab.research.google.com/github/Debojit-D/ES666-CV/blob/main/22110067_Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is submssion template for the assignment 3, Panaroma Stitching.
#
# Refer https://github.com/shash29-dev/ES666-Assignment3 to access the assignment.
#
# A `readme.md` file is provided in the repository with instructions.
#
# If you face any issues or have queries, try opening a issue on github itself. All queries will be addressed through github issues only.

# %%
# %cd /content
# !git clone https://github.com/Debojit-D/ES666-Assignment3-New.git  # Change with your Fork


# Want to create backup in your drive?
# from google.colab import drive
# drive.mount('/content/drive')
# !cp /content/ES666-Assignment3 /content/drive/MyDrive/ES666_Assignment3  # This Path should Exist In your drive!
# Out:
# /content
# Cloning into 'ES666-Assignment3-New'...
# remote: Enumerating objects: 206, done.
# remote: Total 206 (delta 0), reused 0 (delta 0), pack-reused 206 (from 1)
# Receiving objects: 100% (206/206), 199.52 MiB | 24.21 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
# %cd ES666-Assignment3-New
# Out:
# /content/ES666-Assignment3-New

# %%
# !python main.py
# Out:
# **************** Running Awesome Stitcher developed by: Debojit | 1 of 4 ********************
# 		 Processing... /content/ES666-Assignment3-New/Images/I1
# [array([[ 4.99281813e+00, -1.20443228e+01,  1.52179257e+03],
#        [ 1.92560376e+00, -4.71810692e+00,  7.18784420e+02],
#        [ 2.88805584e-03, -7.06298021e-03,  1.00000000e+00]]), array([[-9.33875021e+00,  2.54643519e+01,  2.59457988e+03],
#        [-2.57802304e+00,  7.03051632e+00,  7.15884371e+02],
#        [-3.59936175e-03,  9.81454251e-03,  1.00000000e+00]]), array([[-2.94116741e-05, -2.81705377e-02,  4.61554390e+01],
#        [-4.40574501e-04, -4.21999370e-01,  6.91416329e+02],
#        [-6.37224526e-07, -6.10340466e-04,  1.00000000e+00]]), array([[-4.39614889e-01, -3.75659907e-01,  1.64238496e+03],
#        [-1.63267074e-01, -4.39892353e-02,  4.80072532e+02],
#        [-2.01350262e-04, -3.80393775e-04,  1.00000000e+00]]), array([[-7.31540271e-01,  1.10808828e-01,  1.97076450e+03],
# ...

# %% [markdown]
# When I run the code locally there is no issue all the images are generated as expected but in Collab even though I haven't had any keyboard interrupt it runs for Image 1 and then displays and interrupt signal "^C".. Hence I have run the codes locally and updated the images online. If you are checking this assignment and want to verify my local repository please contact me : Debojit Das (22110067) | Email : debojit.das@iitgn.ac.in | Ph No : 8637054143, 9609018007

# %%
import matplotlib.pyplot as plt
import glob
allims = glob.glob('./results/*/Debojit_stitcher*.png')  # replace JaneDoe by your folder name
for im in allims:
  plt.figure()
  plt.axis('off')
  plt.imshow(plt.imread(im))
